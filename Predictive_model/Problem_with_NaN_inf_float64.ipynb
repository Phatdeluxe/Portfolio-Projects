# %%
import pandas as pd


X_train = pd.read_csv('https://raw.githubusercontent.com/Phatdeluxe/Portfolio-Projects/master/Predictive_model/X_train.txt', index_col='Unnamed: 0')
y_train = pd.read_csv('https://raw.githubusercontent.com/Phatdeluxe/Portfolio-Projects/master/Predictive_model/y_train.txt', names=['target'])

# %%
pd.set_option('display.max_columns', None)

# %%
X_train.describe()
# Out:
#        LACCESS_POP10  PCT_LACCESS_POP10  LACCESS_LOWI10  PCT_LACCESS_LOWI10  \
# count    2011.000000        2011.000000     2011.000000         2011.000000
# mean    20931.243963          23.466214     5737.523351            8.354613
# std     53943.289773          20.104061    14336.754542            8.171630
# min         0.000000           0.000000        0.000000            0.000000
# 25%      1702.132722          11.088581      609.807457            3.480040
# 50%      4237.405553          19.589908     1530.882711            6.107436
# 75%     12812.528175          29.139910     4618.883357           10.346669
# max    886068.668400         100.000001   292541.789000           72.274456
#
#        LACCESS_HHNV10  PCT_LACCESS_HHNV10  LACCESS_CHILD10  \
# count     2011.000000         2011.000000      2011.000000
# mean       663.845210            3.097317      5182.655821
# std       1103.037795            2.769967     13929.268129
# ...

# %%
y_train.describe()
# Out:
#             target
# count  2010.000000
# mean     11.227463
# std       2.473538
# min       4.100000
# 25%       9.500000
# 50%      11.100000
# 75%      12.875000
# max      20.100000

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    LinearRegression()
)

# %%
pipeline.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-58e3b7912133> in <module>
# ----> 1 pipeline.fit(X_train, y_train)
#
# ~\Anaconda3\envs\Unit 2\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     354                                  self._log_message(len(self.steps) - 1)):
#     355             if self._final_estimator != 'passthrough':
# --> 356                 self._final_estimator.fit(Xt, y, **fit_params)
#     357         return self
#     358
#
# ~\Anaconda3\envs\Unit 2\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
# ...
